# %% [markdown]
# # Об альтернативных подсчетах "голосом"
#
# - toc: false
# - badges: false
# - comments: false
# - permalink: /election-map/
# - categories: [аналитика]

# %%
# hide
# %load_ext nb_black
# %config IPCompleter.greedy=True
import pdb

# %%
#hide

# todo: add kpdv via - image: images/chart-preview.png
import folium
import pandas as pd
from IPython.display import HTML, IFrame

# %%
# hide
df = pd.read_csv("/nbs/jupyter-dev-01/nbs/uber_votes.csv")
green = df[df["lukashenko"] > df["tihanovskaja"]]
red = df[df["lukashenko"] < df["tihanovskaja"]]
gray = df[df["voters"].isna()]

# %%
# hide
m = folium.Map(location=[53.893009, 27.567444])

green.apply(
    lambda row: folium.CircleMarker(
        location=[row["latitude"], row["longitude"]],
        radius=4,
        weight=2,
        opacity=0.8,
        color="green",
    ).add_to(m),
    axis=1,
)

red.apply(
    lambda row: folium.CircleMarker(
        location=[row["latitude"], row["longitude"]],
        radius=4,
        weight=2,
        opacity=0.8,
        color="red",
    ).add_to(m),
    axis=1,
)

gray.apply(
    lambda row: folium.CircleMarker(
        location=[row["latitude"], row["longitude"]],
        radius=4,
        weight=2,
        opacity=0.8,
        color="gray",
    ).add_to(m),
    axis=1,
)


m.save("../assets/attach/election_map.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Условные обозначения:
#
# - красный - участки где преобладают голоса Тихановской
# - серый - не отправлены фотографии протоколов

# %%
# hide_input

# IFrame(src="../assets/attach/election_map.html", width="100%", height=700)
IFrame(src='/platform/assets/attach/election_map.html', width="100%", height=700)
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="../assets/attach/election_map.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
